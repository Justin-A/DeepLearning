# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision import transforms, datasets

# %%
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")

# %%
EPOCHS = 40
BATCH_SIZE = 64

# %%
train_loader = torch.utils.data.DataLoader(datasets.MNIST('./.data',
                                                         train = True,
                                                         download = True,
                                                         transform = transforms.Compose([
                                                             transforms.ToTensor(),
                                                             transforms.Normalize((0.1307, ), (0.3081,))
                                                         ])),
                                          batch_size = BATCH_SIZE, shuffle = True)

# %%
test_loader = torch.utils.data.DataLoader(datasets.MNIST('./.data',
                                                        train = False,
                                                        transform = transforms.Compose([
                                                            transforms.ToTensor(),
                                                            transforms.Normalize((0.1307, ), (0.3031,))
                                                        ])),
                                         batch_size = BATCH_SIZE, shuffle = True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size = 5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size = 5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)
    
    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training = self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim = 1)

# %%
model = Net().to(DEVICE)
optimizer = optim.SGD(model.parameters(), lr = 0.01, momentum = 0.5)

# %%
def train(model, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(DEVICE), target.to(DEVICE)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()
        
        if batch_idx % 200 == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(epoch, batch_idx * len(data), len(train_loader.dataset), 100. * batch_idx / len(train_loader), loss.item()))

# %%
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(DEVICE), target.to(DEVICE)
            output = model(data)
            
            test_loss += F.cross_entropy(output, target, reduction = 'sum').item()
            
            pred = output.max(1, keepdim = True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, epoch)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print('[{}] Test Loss: {:.4f}, Accuracy: {:.2f}%'.format(epoch, test_loss, test_accuracy))
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.586661
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.228047
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.343396
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.393107
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.360426
# [1] Test Loss: 0.1244, Accuracy: 96.13%
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.306252
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.424817
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.239059
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.208025
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.172546
# [2] Test Loss: 0.0957, Accuracy: 97.08%
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.312127
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.372096
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.363630
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.138410
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.268174
# [3] Test Loss: 0.0820, Accuracy: 97.40%
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.288814
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.589109
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.219101
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.201695
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.121565
# [4] Test Loss: 0.0743, Accuracy: 97.68%
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.184613
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.124472
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.244774
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.138621
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.367771
# [5] Test Loss: 0.0669, Accuracy: 97.94%
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.312574
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.286551
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.227055
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.183424
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.184775
# [6] Test Loss: 0.0606, Accuracy: 97.99%
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.198305
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.217967
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.050377
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.085085
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.162048
# [7] Test Loss: 0.0544, Accuracy: 98.33%
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.169775
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.098302
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.253329
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.259742
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.096033
# [8] Test Loss: 0.0512, Accuracy: 98.35%
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.174404
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.455892
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.119206
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.160324
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.256011
# [9] Test Loss: 0.0543, Accuracy: 98.25%
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.170794
# Train Epoch: 10 [12800/60000 (21%)]	Loss: 0.188027
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 0.374802
# Train Epoch: 10 [38400/60000 (64%)]	Loss: 0.176953
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.088939
# [10] Test Loss: 0.0478, Accuracy: 98.49%
# Train Epoch: 11 [0/60000 (0%)]	Loss: 0.204378
# Train Epoch: 11 [12800/60000 (21%)]	Loss: 0.148839
# Train Epoch: 11 [25600/60000 (43%)]	Loss: 0.099631
# Train Epoch: 11 [38400/60000 (64%)]	Loss: 0.113116
# Train Epoch: 11 [51200/60000 (85%)]	Loss: 0.205036
# [11] Test Loss: 0.0476, Accuracy: 98.47%
# Train Epoch: 12 [0/60000 (0%)]	Loss: 0.064767
# Train Epoch: 12 [12800/60000 (21%)]	Loss: 0.090900
# Train Epoch: 12 [25600/60000 (43%)]	Loss: 0.040823
# Train Epoch: 12 [38400/60000 (64%)]	Loss: 0.145150
# Train Epoch: 12 [51200/60000 (85%)]	Loss: 0.145747
# [12] Test Loss: 0.0437, Accuracy: 98.62%
# Train Epoch: 13 [0/60000 (0%)]	Loss: 0.089463
# Train Epoch: 13 [12800/60000 (21%)]	Loss: 0.248137
# Train Epoch: 13 [25600/60000 (43%)]	Loss: 0.236031
# Train Epoch: 13 [38400/60000 (64%)]	Loss: 0.179832
# Train Epoch: 13 [51200/60000 (85%)]	Loss: 0.166678
# [13] Test Loss: 0.0453, Accuracy: 98.55%
# Train Epoch: 14 [0/60000 (0%)]	Loss: 0
# Train Epoch: 33 [51200/60000 (85%)]	Loss: 0.056614
# [33] Test Loss: 0.0322, Accuracy: 98.97%
# Train Epoch: 34 [0/60000 (0%)]	Loss: 0.070151
# Train Epoch: 34 [12800/60000 (21%)]	Loss: 0.240105
# Train Epoch: 34 [25600/60000 (43%)]	Loss: 0.185220
# Train Epoch: 34 [38400/60000 (64%)]	Loss: 0.177646
# Train Epoch: 34 [51200/60000 (85%)]	Loss: 0.212568
# [34] Test Loss: 0.0309, Accuracy: 99.03%
# Train Epoch: 35 [0/60000 (0%)]	Loss: 0.114416
# Train Epoch: 35 [12800/60000 (21%)]	Loss: 0.320068
# Train Epoch: 35 [25600/60000 (43%)]	Loss: 0.066021
# Train Epoch: 35 [38400/60000 (64%)]	Loss: 0.014219
# Train Epoch: 35 [51200/60000 (85%)]	Loss: 0.046285
# [35] Test Loss: 0.0305, Accuracy: 99.06%
# Train Epoch: 36 [0/60000 (0%)]	Loss: 0.025661
# Train Epoch: 36 [12800/60000 (21%)]	Loss: 0.109531
# Train Epoch: 36 [25600/60000 (43%)]	Loss: 0.098031
# Train Epoch: 36 [38400/60000 (64%)]	Loss: 0.271179
# Train Epoch: 36 [51200/60000 (85%)]	Loss: 0.094824
# [36] Test Loss: 0.0318, Accuracy: 99.04%
# Train Epoch: 37 [0/60000 (0%)]	Loss: 0.029796
# Train Epoch: 37 [12800/60000 (21%)]	Loss: 0.123356
# Train Epoch: 37 [25600/60000 (43%)]	Loss: 0.147550
# Train Epoch: 37 [38400/60000 (64%)]	Loss: 0.089209
# Train Epoch: 37 [51200/60000 (85%)]	Loss: 0.191541
# [37] Test Loss: 0.0320, Accuracy: 98.99%
# Train Epoch: 38 [0/60000 (0%)]	Loss: 0.138801
# Train Epoch: 38 [12800/60000 (21%)]	Loss: 0.022196
# Train Epoch: 38 [25600/60000 (43%)]	Loss: 0.096822
# Train Epoch: 38 [38400/60000 (64%)]	Loss: 0.061551
# Train Epoch: 38 [51200/60000 (85%)]	Loss: 0.172624
# [38] Test Loss: 0.0317, Accuracy: 99.00%
# Train Epoch: 39 [0/60000 (0%)]	Loss: 0.031088
# Train Epoch: 39 [12800/60000 (21%)]	Loss: 0.090182
# Train Epoch: 39 [25600/60000 (43%)]	Loss: 0.215154
# Train Epoch: 39 [38400/60000 (64%)]	Loss: 0.069778
# Train Epoch: 39 [51200/60000 (85%)]	Loss: 0.088472
# [39] Test Loss: 0.0332, Accuracy: 99.02%
# Train Epoch: 40 [0/60000 (0%)]	Loss: 0.218644
# Train Epoch: 40 [12800/60000 (21%)]	Loss: 0.086965
# Train Epoch: 40 [25600/60000 (43%)]	Loss: 0.148060
# Train Epoch: 40 [38400/60000 (64%)]	Loss: 0.050360
# Train Epoch: 40 [51200/60000 (85%)]	Loss: 0.115338
# [40] Test Loss: 0.0304, Accuracy: 99.08%
