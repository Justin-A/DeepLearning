# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Define Model and Loss
class Model(object):
    def __init__(self):
        self.W = tf.Variable(10.0)
        self.b = tf.Variable(-5.0)
        
    def __call__(self, inputs):
        return self.W * inputs + self.b

# %%
def compute_loss(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true - y_pred))

# %%
model = Model()

# %%
# Define true weight & bias
TRUE_W = 3.0
TRUE_b = 2.0

# %%
# Obtain training dat, Let's synthesize the training data with some noise
NUM_EXAMPLES = 1000
inputs = tf.random.normal(shape = [NUM_EXAMPLES])
noise = tf.random.normal(shape = [NUM_EXAMPLES])
outputs = inputs * TRUE_W + TRUE_b + noise

# %%
def plot(epoch):
    plt.scatter(inputs, outputs, c = 'b')
    plt.scatter(inputs, model(inputs), c = 'r')
    plt.title("Epoch %2d, loss = %s" % (epoch, str(compute_loss(outputs, model(inputs)).numpy())))
    plt.legend()
    plt.draw()
    plt.ion()
    plt.pause(1)
    plt.close()

# %%
# Define a training loop
learning_rate = 0.1
for epoch in range(30):
    with tf.GradientTape() as tape:
        loss = compute_loss(outputs, model(inputs))
    
    dW, db = tape.gradient(loss, [model.W, model.b])
    model.W.assign_sub(learning_rate * dW)
    model.b.assign_sub(learning_rate * db)
    
    print("=> Epoch %2d: w_true = %.2f, w_pred = %.2f, b_true = %.2f, b_pred = %.2f, loss = %.2f" 
          %(epoch + 1, TRUE_W, model.W.numpy(), TRUE_b, model.b.numpy(), loss.numpy()))
    plot(epoch + 1)
# Out:
# No handles with labels found to put in legend.
# => Epoch  1: w_true = 3.00, w_pred = 8.63, b_true = 2.00, b_pred = -3.67, loss = 95.46
# No handles with labels found to put in legend.
# => Epoch  2: w_true = 3.00, w_pred = 7.53, b_true = 2.00, b_pred = -2.59, loss = 62.45
# No handles with labels found to put in legend.
# => Epoch  3: w_true = 3.00, w_pred = 6.64, b_true = 2.00, b_pred = -1.71, loss = 40.97
# No handles with labels found to put in legend.
# => Epoch  4: w_true = 3.00, w_pred = 5.93, b_true = 2.00, b_pred = -1.01, loss = 27.00
# No handles with labels found to put in legend.
# => Epoch  5: w_true = 3.00, w_pred = 5.36, b_true = 2.00, b_pred = -0.44, loss = 17.90
# No handles with labels found to put in legend.
# => Epoch  6: w_true = 3.00, w_pred = 4.90, b_true = 2.00, b_pred = 0.03, loss = 11.98
# No handles with labels found to put in legend.
# => Epoch  7: w_true = 3.00, w_pred = 4.52, b_true = 2.00, b_pred = 0.40, loss = 8.12
# No handles with labels found to put in legend.
# => Epoch  8: w_true = 3.00, w_pred = 4.23, b_true = 2.00, b_pred = 0.70, loss = 5.61
# No handles with labels found to put in legend.
# => Epoch  9: w_true = 3.00, w_pred = 3.98, b_true = 2.00, b_pred = 0.95, loss = 3.98
# No handles with labels found to put in legend.
# => Epoch 10: w_true = 3.00, w_pred = 3.79, b_true = 2.00, b_pred = 1.14, loss = 2.92
# No handles with labels found to put in legend.
# => Epoch 11: w_true = 3.00, w_pred = 3.64, b_true = 2.00, b_pred = 1.30, loss = 2.23
# No handles with labels found to put in legend.
# => Epoch 12: w_true = 3.00, w_pred = 3.51, b_true = 2.00, b_pred = 1.43, loss = 1.78
# No handles with labels found to put in legend.
# => Epoch 13: w_true = 3.00, w_pred = 3.41, b_true = 2.00, b_pred = 1.54, loss = 1.48
# No handles with labels found to put in legend.
# => Epoch 14: w_true = 3.00, w_pred = 3.33, b_true = 2.00, b_pred = 1.62, loss = 1.29
# No handles with labels found to put in legend.
# => Epoch 15: w_true = 3.00, w_pred = 3.26, b_true = 2.00, b_pred = 1.69, loss = 1.17
# No handles with labels found to put in legend.
# => Epoch 16: w_true = 3.00, w_pred = 3.21, b_true = 2.00, b_pred = 1.75, loss = 1.09
# No handles with labels found to put in legend.
# => Epoch 17: w_true = 3.00, w_pred = 3.17, b_true = 2.00, b_pred = 1.79, loss = 1.03
# No handles with labels found to put in legend.
# => Epoch 18: w_true = 3.00, w_pred = 3.13, b_true = 2.00, b_pred = 1.83, loss = 1.00
# No handles with labels found to put in legend.
# => Epoch 19: w_true = 3.00, w_pred = 3.11, b_true = 2.00, b_pred = 1.86, loss = 0.98
# No handles with labels found to put in legend.
# => Epoch 20: w_true = 3.00, w_pred = 3.08, b_true = 2.00, b_pred = 1.88, loss = 0.96
# No handles with labels found to put in legend.
# => Epoch 21: w_true = 3.00, w_pred = 3.07, b_true = 2.00, b_pred = 1.90, loss = 0.95
# No handles with labels found to put in legend.
# => Epoch 22: w_true = 3.00, w_pred = 3.05, b_true = 2.00, b_pred = 1.92, loss = 0.95
# No handles with labels found to put in legend.
# => Epoch 23: w_true = 3.00, w_pred = 3.04, b_true = 2.00, b_pred = 1.93, loss = 0.94
# No handles with labels found to put in legend.
# => Epoch 24: w_true = 3.00, w_pred = 3.03, b_true = 2.00, b_pred = 1.94, loss = 0.94
# No handles with labels found to put in legend.
# => Epoch 25: w_true = 3.00, w_pred = 3.02, b_true = 2.00, b_pred = 1.95, loss = 0.94
# No handles with labels found to put in legend.
# => Epoch 26: w_true = 3.00, w_pred = 3.02, b_true = 2.00, b_pred = 1.95, loss = 0.94
# No handles with labels found to put in legend.
# => Epoch 27: w_true = 3.00, w_pred = 3.01, b_true = 2.00, b_pred = 1.96, loss = 0.94
# No handles with labels found to put in legend.
# => Epoch 28: w_true = 3.00, w_pred = 3.01, b_true = 2.00, b_pred = 1.96, loss = 0.94
# No handles with labels found to put in legend.
# => Epoch 29: w_true = 3.00, w_pred = 3.01, b_true = 2.00, b_pred = 1.97, loss = 0.94
# No handles with labels found to put in legend.
# => Epoch 30: w_true = 3.00, w_pred = 3.00, b_true = 2.00, b_pred = 1.97, loss = 0.94
